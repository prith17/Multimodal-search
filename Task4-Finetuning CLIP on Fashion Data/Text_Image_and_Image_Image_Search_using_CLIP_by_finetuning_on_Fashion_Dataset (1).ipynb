# %% [markdown]
# #Text-Image Search and Image-Image Search using CLIP Approach by Finetuning on Custom Dataset

# %% [markdown]
# #1. Installing dependencies

# %%
# !pip install torch==2.0.0 -f https://download.pytorch.org/whl/cu111/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/cu111/torch_stable.html
# Collecting torch==2.0.0
#   Downloading torch-2.0.0-cp310-cp310-manylinux1_x86_64.whl (619.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0) (3.1.2)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch==2.0.0)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 76.2 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch==2.0.0)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 65.0 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch==2.0.0)
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 95.4 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch==2.0.0)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.9 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch==2.0.0)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.3 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch==2.0.0)
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 6.6 MB/s eta 0:00:00
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch==2.0.0)
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 12.1 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch==2.0.0)
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 8.7 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch==2.0.0)
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 6.7 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu11==2.14.3 (from torch==2.0.0)
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 6.4 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch==2.0.0)
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.0) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.0) (0.40.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.0) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.0) (16.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.0) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.0) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, nvidia-cusolver-cu11, nvidia-cudnn-cu11, torch
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 2.0.0 which is incompatible.
# torchdata 0.6.1 requires torch==2.0.1, but you have torch 2.0.0 which is incompatible.
# torchtext 0.15.2 requires torch==2.0.1, but you have torch 2.0.0 which is incompatible.
# torchvision 0.15.2+cu118 requires torch==2.0.1, but you have torch 2.0.0 which is incompatible.
# Successfully installed nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 torch-2.0.0

# %%
# !pip uninstall -y torchaudio torchdata torchtext torchvision
# Out:
# Found existing installation: torchaudio 2.0.2+cu118
# Uninstalling torchaudio-2.0.2+cu118:
#   Successfully uninstalled torchaudio-2.0.2+cu118
# Found existing installation: torchdata 0.6.1
# Uninstalling torchdata-0.6.1:
#   Successfully uninstalled torchdata-0.6.1
# Found existing installation: torchtext 0.15.2
# Uninstalling torchtext-0.15.2:
#   Successfully uninstalled torchtext-0.15.2
# Found existing installation: torchvision 0.15.2+cu118
# Uninstalling torchvision-0.15.2+cu118:
#   Successfully uninstalled torchvision-0.15.2+cu118

# %%
# !pip install torchvision
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchvision
#   Downloading torchvision-0.15.2-cp310-cp310-manylinux1_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 95.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.27.1)
# Collecting torch==2.0.1 (from torchvision)
#   Downloading torch-2.0.1-cp310-cp310-manylinux1_x86_64.whl (619.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (8.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchvision) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchvision) (0.40.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->torchvision) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->torchvision) (16.0.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.1->torchvision) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.1->torchvision) (1.3.0)
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0
#     Uninstalling torch-2.0.0:
#       Successfully uninstalled torch-2.0.0
# Successfully installed torch-2.0.1 torchvision-0.15.2

# %%
# !pip install -qU transformers torch datasets gdcm pydicom pinecone-client
# !pip install openai-clip
# !pip install gdcm
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 23.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 48.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 96.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 87.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.2/177.2 kB 20.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 17.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 80.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 11.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 19.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 14.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 63.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 32.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 13.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 34.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 18.9 MB/s eta 0:00:00
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openai-clip
#   Downloading openai-clip-1.0.1.tar.gz (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 44.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ftfy (from openai-clip)
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from openai-clip) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai-clip) (4.65.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy->openai-clip) (0.2.6)
# Building wheels for collected packages: openai-clip
#   Building wheel for openai-clip (setup.py) ... done
#   Created wheel for openai-clip: filename=openai_clip-1.0.1-py3-none-any.whl size=1368607 sha256=1a8aa186e684163d1eed168a7fd492150f31b110eee4b97261d3417de0ace59a
#   Stored in directory: /root/.cache/pip/wheels/08/77/8e/8d2f862df6bf7fb4e2007062d2cbaeae49862ec7b56d041229
# Successfully built openai-clip
# Installing collected packages: ftfy, openai-clip
# Successfully installed ftfy-6.1.1 openai-clip-1.0.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdcm in /usr/local/lib/python3.10/dist-packages (1.1)

# %% [markdown]
# #2. Importing required libraries

# %%
import os
import torch
import skimage
import requests
import numpy as np
import pandas as pd
from PIL import Image
from io import BytesIO
import IPython.display
import matplotlib.pyplot as plt
from datasets import load_dataset
from collections import OrderedDict
from transformers import CLIPProcessor, CLIPModel, CLIPTokenizer
import torch
import clip
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# # 3. Loading Train Dataset for finetuning

# %%
# https://huggingface.co/datasets/conceptual_captions
image_data = load_dataset(
    "ashraq/fashion-product-images-small", split="train",
    )
# Out:
# Downloading readme:   0%|          | 0.00/867 [00:00<?, ?B/s]
# Downloading and preparing dataset None/None to /root/.cache/huggingface/datasets/ashraq___parquet/ashraq--fashion-product-images-small-909c61a107795b31/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/136M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/135M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/44072 [00:00<?, ? examples/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/ashraq___parquet/ashraq--fashion-product-images-small-909c61a107795b31/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.

# %%
image_data_df = pd.DataFrame(image_data[:200])

# %%
image_data_df.shape
# Out:
# (1000, 11)

# %%
image_data_df.head()
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
#
#      year   usage                             productDisplayName  \
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt
# 1  2012.0  Casual             Peter England Men Party Blue Jeans
# 2  2016.0  Casual                       Titan Women Silver Watch
# 3  2011.0  Casual  Manchester United Men Solid Black Track Pants
# 4  2012.0  Casual                          Puma Men Grey T-shirt
#
#                                                image
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 2  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 3  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 4  <PIL.JpegImagePlugin.JpegImageFile image mode=...

# %%
image_data_df.shape
# Out:
# (1000, 11)

# %%
image_data_df.iloc[2]["image"]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=60x80 at 0x7F1D5362BE20>

# %%
image_data_df.iloc[2]["productDisplayName"]
# Out:
# 'Titan Women Silver Watch'

# %%
image_data_df.head()
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
#
#      year   usage                             productDisplayName  \
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt
# 1  2012.0  Casual             Peter England Men Party Blue Jeans
# 2  2016.0  Casual                       Titan Women Silver Watch
# 3  2011.0  Casual  Manchester United Men Solid Black Track Pants
# 4  2012.0  Casual                          Puma Men Grey T-shirt
#
#                                                image
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 2  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 3  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 4  <PIL.JpegImagePlugin.JpegImageFile image mode=...

# %%
# Define your custom dataset
class CustomDataset(Dataset):
    def __init__(self, image_paths, texts):
        self.image_paths = image_paths
        self.texts = texts
        self.transform = transforms.Compose([
            transforms.Resize(224),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        text = self.texts[idx]
        image = self.transform(self.image_paths[idx].convert("RGB"))
        return image, text

# %%
# Define your dataset paths and texts
image_paths = image_data_df["image"].tolist()
texts = image_data_df["productDisplayName"].tolist()

# %%
print(image_paths)
# Out:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D5362BD30>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D5362BD90>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=60x80 at 0x7F1D5362BE20>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D5362BEB0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72524130>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D725241C0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72524400>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72524490>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72524520>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72524760>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72524A60>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72524CA0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72524D30>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72524F70>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72525180>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72525390>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D725255D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72525810>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72525A50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72525AE0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72525D20>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72525F30>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72525F90>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72526020>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72526260>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D725262F0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72526530>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72526830>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72526B30>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72526BC0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72526E00>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72527040>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D725270D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D725272E0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72527370>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D725275B0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D725277F0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72527940>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72527BB0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72527DF0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D72527FD0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D6E4D8250>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D6E4D8490>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D6E4D8520>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D6E4D85B0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D6E4D8700>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D6E4D8940>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D6E4D8B50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D6E4D8D90>, <PIL.JpegImagePlugin.JpegImageFi ...

# %%
print(texts)
# Out:
# ['Turtle Check Men Navy Blue Shirt', 'Peter England Men Party Blue Jeans', 'Titan Women Silver Watch', 'Manchester United Men Solid Black Track Pants', 'Puma Men Grey T-shirt', 'Inkfruit Mens Chain Reaction T-shirt', 'Fabindia Men Striped Green Shirt', 'Jealous 21 Women Purple Shirt', 'Puma Men Pack of 3 Socks', 'Skagen Men Black Watch', 'Puma Men Future Cat Remix SF Black Casual Shoes', 'Fossil Women Black Huarache Weave Belt', 'Fila Men Cush Flex Black Slippers', 'Murcia Women Blue Handbag', 'Ben 10 Boys Navy Blue Slippers', 'Reid & Taylor Men Check Purple Shirts', 'Police Men Black Dial Watch PL12889JVSB', 'Gini and Jony Girls Knit White Top', 'Bwitch Beige Full-Coverage Bra BW335', 'Baggit Women Brown Handbag', 'CASIO G-Shock Men Black Digital Watch G-7710-1DR G223', 'ADIDAS Men Spry M Black Sandals', 'Timberland Unisex Rubber Sole Brush Shoe Accessories', 'ADIDAS Men Lfc Auth Hood Grey Sweatshirts', 'David Beckham Signature Men Deos', 'Buckaroo Men Flores Black Formal Shoes', 'Pitaraa Women Bronze Beaded Bracelet', "Fila Men's Round Neck Navy Blue T-shirt", 'Colorbar Soft Touch Show Stopper Copper Lipstick 037', 'Murcia Women Casual Brown Handbag', 'John Players Men Navy Blue Shirt', "Disney Kids Boy's Crew Sea Life Sialing Green Teen Kidswear", 'John Players Men Brown Shirt', 'Gas Men Europa White Shoes', 'Carlton London Women Black & Gold Toned Flats', 'Diva Women Embroided Green Kurta', 'Rocky S Women White Handbag', 'Kiara Women Teal Handbag', 'Fossil Women Copper Chronograph Watch CH2589', "Jealous 21 Women's Pink T-shirt", 'Peter England Men Formal Black Belt', 'Catwalk Women Leather Brown Flats', 'Maxima Ssteele Men Off White Watch', 'W Women Printed Beige Kurta', 'Scullers Men  Grey Waistcoat', "Nike Men's Incinerate MSL White Blue Shoe", 'Puma Men Long Logo Black Bermuda', 'Levis Men Boxer Maroon Brief', 'John Miller Men Stripes White Red Shirts', 'Baggit Women Hood Dabang Black Belt', 'Maxima Women White Dial Watch', 'Clarks Men Hang Work Leather Black Formal Shoes', 'Vishudh Women Brown Kurta', 'Playboy Men Blue Titanium Briefs', 'Arrow Men Black Formal Shoes', "Puma Men's Stripe Polo Black T-shirt", 'Nike Women Purple Polo T-shirt', "Gini and Jony Boy's Kaleb White Brown Kidswear", 'Carrera Men Dial steel finish strap Silver Watches', 'Wrangler Men Motor Rider Red T-Shirts', 'FNF Pink & Grey Wedding Collection Sari', 'Puma Men Scribble Black Tshirts', 'CASIO EDIFICE Men Black Dial Chronograph Watch ED60', 'French Connection Women Beige Handbag', 'Timberland Men Black Casual Shoes', 'Vans Men Classic Slip-On Purple & Black Shoes', 'Police Women Passion Perfume', "ADIDAS Men's Lowell White Silver Shoe", 'Do U Speak Green Men Blue Shorts', 'ID Men Red Shoes', 'Peperone Women Black & White Handbag', 'Vans Men Khaki Shoes', 'Indigo Nation Men Reversible Bling Pink Shirts', 'Nike Women Black T-shirt', 'ADIDAS Men Blue Sweatshirt', 'Manchester United Men Solid Red Tshirt', 'Rocia Women Black Flats', 'Catwalk Women Leather Flats', 'Mineral Women Green Top', 'Crocs Dora Boots Pink Sandals', 'Image Men Sunglasses', 'Lotto Men XL Water Man Silver Slippers', 'United Colors of Benetton Men Solid Pink Polo T-shirts', 'Levis Men Comfort Style Grey Innerwear Vest', 'Reebok Men Black Possession Flip Flops', 'Lucera Women Silver Pendant', 'Maxima Men White Dial Analog Chronograph Watch', 'Peter England Unisex Orange Sleeve Bag', 'Puma Men Axis White & Grey Sports Shoes', 'Tonga Women Maroon Top', 'Femella Women Brown Scarf', "ADIDAS Men's Twelve Faster T-shirt", 'Arrow Woman Women Blue Dress', 'Levis Men Red Brief', 'Ganuchi Men Casual Black Sandals', 'SDL by Sweet Dreams Women Green Printed Night Suit S11-3124', 'Indigo Nation Men Printed Black T-shirt', 'DKNY Women Red Delicious Perfume', 'Urban Yoga Women Blue Skirt With Leggings', 'Gini and Jony Girls Black Top', 'Nike Men Air Rift MTR White Casual Shoe', 'ADIDAS Men White Corona Sports Shoes', 'Fastrack Unisex Black Dial Watch 9915PP13', 'Vans Men Blue Era Scilla Plaid Sho ...

# %% [markdown]
# # 5. Loading pretrained CLIP Model of ViT variant

# %% [markdown]
# ![CLIP.png](data:image/png;base64,...)

# %%
# Initialize and load the pre-trained CLIP model
device = "cuda" if torch.cuda.is_available() else "cpu"

#https://github.com/openai/CLIP
# device = "cuda" if torch.cuda.is_available() else "cpu"
# model, preprocess = clip.load("ViT-B/32", device=device)



# https://huggingface.co/openai/clip-vit-base-patch32
model_ID='openai/clip-vit-base-patch32'

# Get the processor
processor = CLIPProcessor.from_pretrained(model_ID)


# Save the model to device
model = CLIPModel.from_pretrained(model_ID).to(device)

# Get the tokenizer
tokenizer = CLIPTokenizer.from_pretrained(model_ID)

# %%
# Create an instance of your custom dataset
dataset = CustomDataset(image_paths, texts)

# %%
# Define training parameters
batch_size = 32
learning_rate = 1e-5

# Create a data loader
data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# Set up optimizer and loss function
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
criterion = torch.nn.CosineEmbeddingLoss()

# %%
# from PIL import Image

# def pil_loader(path):
#     with open(path, 'rb') as f:
#         img = Image.open(f)
#         return img.convert('RGB')

# # Define your custom dataset
# class CustomDataset(Dataset):
#     def __init__(self, image_paths, texts):
#         self.image_paths = image_paths
#         self.texts = texts
#         self.transform = transforms.Compose([
#             transforms.Resize(224),
#             transforms.CenterCrop(224),
#             transforms.ToTensor(),
#            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
#         ])

#     def __len__(self):
#         return len(self.image_paths)

#     def __getitem__(self, idx):
#         text = self.texts[idx]
#         img = Image.open(image_paths[idx]).convert('RGB')
#         image = self.transform(img)
#         return image, text


# image_paths = image_data_df["image"].tolist()
# texts = image_data_df["productDisplayName"].tolist()

# dataset = CustomDataset(image_paths, texts)

# # Define training parameters
# batch_size = 32
# learning_rate = 1e-5

# # Create a data loader
# data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# # Set up optimizer and loss function
# optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# criterion = torch.nn.CosineEmbeddingLoss()

# %%
print(data_loader)

for images,texts in data_loader:
    print(images,texts)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7f1d78541540>
# tensor([[[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         ...,
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4111, 2.4111, 2.4111,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4111, 2.4111, 2.4111,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4111, 2.4111, 2.4111,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]]]) ('U.S. Polo Assn. Men Stripes Blue Polo Tshirt', 'Fastrack Women Nylon Black Handbag', 'ADIDAS Men Lfc Auth Hood Grey Sweatshirts', 'Wrangler Men Green Striped Shirt', 'Sushilas Women Multi Coloured Kurta', 'Lotto Women XL Kelly Pink Slippers', 'Pitaraa Silver Omelette Thin Bracelet', 'Levis Men Comfort Style White Innerwear Vest', 'Revlon Super Lustrous Plum Baby Lipstick 313', 'Flying Machine Men Walnut Brown Tshirts', 'ADIDAS Men Navy Blue Benton Sandals', 'Puma Men Black Aquil II Sports Shoes', 'Rockport Men LLandro Red Casual Shoes', 'Sepia Women Pink Top', 'Mumbai Slang Women Pink & Black Kurti', 'iPanema Women Blue Flip Flops', 'ADIDAS Unisex Blue Backpack', 'Tonga Women Maroon Top', 'Nike Women Black T-shirt', 'Nike Men Black Sweatshirt', 'Lee Men Solid Blue Shirts', 'Carlton London Women Black & Gold Toned Flats', 'Kalenji Ekiden Comfort Prime 2011', 'Footfun Kids Unisex Red Shoes', 'Wrangler Men Heavy Grey Tshirt', 'Fastrack Men White Dial Watch', 'Wrangler Men Furious Rides Navy Blue T-Shirts', 'Jealous 21 Women Washed Blue Jeans', 'Mark Taylor Men Plain Blue Shirts', 'Lino Perros Women Leatherite Brown Handbag', 'Locomotive Men Printed Charcoal T-shirt', 'Lotus Herbals Moistpetals Rudy Pink Lipstick 140')
# tensor([[[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[1.3070, 1.3070, 1.3070,  ..., 1.2385, 1.2385, 1.2385],
#           [1.3070, 1.3070, 1.3070,  ..., 1.2385, 1.2385, 1.2385],
#           [1.3070, 1.3070, 1.3070,  ..., 1.2385, 1.2385, 1.2385],
#           ...,
#           [1.3070, 1.3070, 1.3070,  ..., 1.2385, 1.2385, 1.2385],
#           [1.3070, 1.3070, 1.3070,  ..., 1.2385, 1.2385, 1.2385],
#           [1.3070, 1.3070, 1.3070,  ..., 1.2385, 1.2385, 1.2385]],
#
#          [[1.4132, 1.4132, 1.4132,  ..., 1.3431, 1.3431, 1.3431],
#           [1.4132, 1.4132, 1.4132,  ..., 1.3431, 1.3431, 1.3431],
#           [1.4132, 1.4132, 1.4132,  ..., 1.3431, 1.3431, 1.3431],
#           ...,
#           [1.4132, 1.4132, 1.4132,  ..., 1.3431, 1.3431, 1.3431],
#           [1.4132, 1.4132, 1.4132,  ..., 1.3431, 1.3431, 1.3431],
#           [1.4132, 1.4132, 1.4132,  ..., 1.3431, 1.3431, 1.3431]],
#
#          [[1.5071, 1.5071, 1.5071,  ..., 1.4722, 1.4722, 1.4722],
#           [1.5071, 1.5071, 1.5071,  ..., 1.4722, 1.4722, 1.4722],
#           [1.5071, 1.5071, 1.5071,  ..., 1.4722, 1.4722, 1.4722],
#           ...,
#           [1.5071, 1.5071, 1.5071,  ..., 1.4722, 1.4722, 1.4722],
#           [1.5071, 1.5071, 1.5071,  ..., 1.4722, 1.4722, 1.4722],
#           [1.5071, 1.5071, 1.5071,  ..., 1.4722, 1.4722, 1.4722]]],
#
#
#         ...,
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4111, 2.4111, 2.4111,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4111, 2.4111, 2.4111,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4111, 2.4111, 2.4111,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]]]) ('DKNY Women White Dial Watch NY8472', 'Jack & Jones Men Dino White T-shirt', 'CSK Mens Fangear Yellow Jersey', 'Arrow Men Navy Blue Solid Trousers', 'Jealous 21 Women Printed Teal T-shirt', 'Nike Men Printed Black T-shirt', 'U.S. Polo Assn. Men Stripes Black  Polo Tshirt', 'Colorbar Soft Touch Spring Fling Lipstick 023', 'Fabindia Women Anusuya Silver Earrings', 'Lucera Women Silver Pendant', 'Image Women Classic Eyewear Brown Sunglasses', "Nike Men's Colors Team India T-shirt", 'Carlton London Men Formal Brown Formal Shoes', 'John Players Men Beige Shorts', 'Nike Women Beige Dunk High Casual Shoes', 'Reebok Reebounce Women Perfumes', "Gini and Jony Girl's Vanya White Polka Dot Kidswear", 'Kiara Women Brown Handbag', "ADIDAS Men's Stripe Black T-shirt", "Lotto Men's Thong Blue White Flip Flop", 'United Colors Of Benetton Women Light Winter Grey Tops', 'Puma Men Pack of 3 Socks', 'Jockey Women Black Lounge Pants', 'Fossil Women Copper Chronograph Watch CH2589', 'Ganuchi Men Casual Olive Sandals', 'Arrow Men Black Formal Shoes', 'FNF Khaki Collection for Wedding Sari', "UCB Men's Making Light Pink T-shirt", 'Titan Men White Dial Watch', 'Wrangler Men Applique Navy Blue Tshirt', 'Enroute Men Leather Brown Casual Shoes', 'Puma Men Puma runhard tee Grey Tshirts')
# tensor([[[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         ...,
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.5703, 2.5703, 2.5703,  ..., 2.6400, 2.6400, 2.6400],
#           [2.5703, 2.5703, 2.5703,  ..., 2.6400, 2.6400, 2.6400],
#           [2.5703, 2.5703, 2.5703,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]]]) ('Lee Men Blue Chicago Fit Jeans', 'Lovable Women Fiona Purple Bra', 'Baggit Women Black Voodoo Gang Handbag', 'Elle Women Green Essentials Top', 'ADIDAS Men Vigor Blue Casual Shoes', 'W Women Peach Kurta', "Classic Polo Men's Swiss Yellow T-shirt", 'ADIDAS Kids Boys Duramo Synthetic Black Sports Shoes', 'French Connection Women Off White Top', 'Converse Unisex Black Shoes', 'United Colors Of Benetton Men Summer Black Shirts', 'Ben 10 Boys Navy Blue Slippers', 'Fastrack Men Economy 2 Analg Black Watch', 'Gini and Jony Girls Knit White Top', 'Indigo Nation Men Bling Red Black Shirts', 'Turtle Check Men Navy Blue Shirt', 'United Colors of Benetton Women Solid Red Wallets', 'Indian Terrain Men Blue T-shirt', "UCB Men's Johny Collar With Two Tone Grey T-shirt", 'Police Men Black Dial Watch PL12170JSB', 'Nike Women Solid Pink Shorts', 'ADIDAS Original Men Black Dial Chronograph Watch ADH2641', 'Lee Cooper Men Brown Casual Sandals', 'John Miller Men Stripes Blue Shirts', 'Locomotive Men Checked Green Shirt', "ADIDAS Men's Boris White Shoe", "Mr.Men Men's Wave Rider White T-shirt", 'Wildcraft Unisex Black Backpack', 'Rockport Men Jelba Brown Flip Flops', 'Aneri Women Ashna Blue Kurta', "Disney Kids Girl's Summer Fun Fair Yellow Teen Kidswear", 'Hanes Men Black Ultimate Duo Dry Cotton Stretch Bikini Briefs')
# tensor([[[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.1462, 2.1462, 2.1462,  ..., 2.2489, 2.2489, 2.2489],
#           [2.1804, 2.1804, 2.1804,  ..., 2.2489, 2.2489, 2.2489],
#           [2.1975, 2.1975, 2.1975,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.3761, 2.3761, 2.3761,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4111, 2.4111, 2.3936,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4111,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4111, 2.4111, 2.4111,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4111, 2.4111, 2.4111,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4111, 2.4111, 2.4111,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.5877, 2.5877, 2.5703,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6226, 2.6226, 2.6051,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6226,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         ...,
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]]]) ('United Colors of Benetton Women White Top', 'Reid & Taylor Men Check Purple Shirts', 'Lovable Women All Day Long Black Bra', 'Titan Men Gold Dial Watch', 'Baggit Women Brown Handbag', 'Nike Men Zoom Structure White Sports Shoes', 'Enroute Women Casual Black Flats', 'Allen Solly Kids Girls Poplin Pink Shorts', 'Puma Men Poly Knitted Black Tracksuit', 'Mark Taylor Men Printed Maroon T-shirt', 'Fossil Women Black Huarache Weave Belt', 'Puma Women Grace Silver Sandals', 'ADIDAS Men Sports Blue Sports Shoes', 'Gas Men Eldorado Tan Casual  Sandals', 'Puma Women Kuris Silver & Grey Sports Shoes', 'SDL by Sweet Dreams Women Pink & Black Printed Night Suit S11-3134', "Tantra Men's Prism Black T-shirt", 'Catwalk Women Bronze toned Sandals', 'Aneri Women Pink & White Kurta', 'Lotto Men Atlantica Black Sports Shoe', 'Numero Uno Men Navy Blue Casual Shoes', 'Lee Cooper Men Black Sports Shoes', 'Nike Women Free Run Pink Sports Shoes', 'Fabindia Men Striped Green Shirt', 'Pal Zileri Men Casual Steel Frame Sunglasses', 'Red Rose White & Green Nightdress', 'Wrangler Cowboy Photo T-shirt', 'Catwalk Women Red Flats', 'Arrow Woman Brown Jeggings', 'CASIO G-Shock Men White Analogue & Digital Watch G274', 'Carlton London Women Blue & Cream Shoes', 'Morellato Men Navy Blue Watch')
# tensor([[[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[1.8208, 1.8208, 1.8208,  ..., 2.2489, 2.2489, 2.2489],
#           [1.7865, 1.7865, 1.7865,  ..., 2.2489, 2.2489, 2.2489],
#           [1.7694, 1.7694, 1.7865,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.1119, 2.1119, 2.1119,  ..., 2.2489, 2.2489, 2.2489],
#           [2.1119, 2.1119, 2.1119,  ..., 2.2489, 2.2489, 2.2489],
#           [2.1119, 2.1119, 2.1119,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.0259, 2.0259, 1.9909,  ..., 2.4286, 2.4286, 2.4286],
#           [1.9909, 1.9909, 1.9559,  ..., 2.4286, 2.4286, 2.4286],
#           [1.9734, 1.9734, 1.9559,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.2710, 2.2710, 2.2710,  ..., 2.4286, 2.4286, 2.4286],
#           [2.2710, 2.2710, 2.2710,  ..., 2.4286, 2.4286, 2.4286],
#           [2.2710, 2.2710, 2.2710,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.1868, 2.1868, 2.1171,  ..., 2.6400, 2.6400, 2.6400],
#           [2.1520, 2.1520, 2.0648,  ..., 2.6400, 2.6400, 2.6400],
#           [2.1346, 2.1346, 2.0648,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.5703, 2.5703, 2.5703,  ..., 2.6400, 2.6400, 2.6400],
#           [2.5703, 2.5703, 2.5703,  ..., 2.6400, 2.6400, 2.6400],
#           [2.5703, 2.5703, 2.5703,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         ...,
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[1.6667, 1.6667, 1.6495,  ..., 2.0263, 2.0434, 2.0434],
#           [1.6667, 1.6667, 1.6495,  ..., 2.0263, 2.0434, 2.0434],
#           [1.6667, 1.6667, 1.6495,  ..., 2.0263, 2.0434, 2.0434],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[1.0980, 1.0980, 1.1155,  ..., 1.5007, 1.5182, 1.5182],
#           [1.0980, 1.0980, 1.1155,  ..., 1.5007, 1.5182, 1.5182],
#           [1.0980, 1.0980, 1.1155,  ..., 1.5007, 1.5182, 1.5182],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[0.9319, 0.9319, 0.9494,  ..., 1.2805, 1.2980, 1.2980],
#           [0.9319, 0.9319, 0.9494,  ..., 1.2805, 1.2980, 1.2980],
#           [0.9319, 0.9319, 0.9494,  ..., 1.2805, 1.2980, 1.2980],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]]]) ('U.S. Polo Assn. Men Striped Blue Shirt', 'Lencia White Swarovski Pearl Necklace', 'Wrangler Women Stella Green Shirt', 'Estd. 1977 Men Beige & Green Sandals', 'United Colors of Benetton Men Stripes Black Polo T-shirts', 'Timberland Unisex Hiker Round Lace Shoe Accessories', 'iPanema Women Red Flip Flops', 'Scullers Men Price Catch Black Shirts', "Wrangler Men's Greensboro Raw Edge Blue T-shirt", 'Cavallini Women Deo', 'Wrangler Women Black Belt', 'United Colors of Benetton Men Printed White Tshirts', 'Van Heusen Unisex Brown Sunglasses', 'United Colors Of Benetton Women Yellow Muffler', "Puma Men's Winglet II Grey Yellow White Flip Flop", 'Peperone Women Black & White Handbag', 'Reebok Men Navy Twist Sandals', 'Locomotive Men Navy Blue Printed T-shirt', 'Timex Men Black Dial Watch', 'Catwalk Women Silver Flats', 'Puma Men Standpunkt Brown Casual Shoes', 'Rocia Women Black Heels', 'ADIDAS Men Intense Touch  Perfume', 'Doodle Kids Boy Check Green Shirt', 'Inc 5 Women Casual Maroon Sandals', 'Rocia Women Copper Sandals', 'Basics Men Navy Shirt', 'Inc.5  Women Grey Flats', 'French Connection Women Blue Top', 'Nike Fragrances Women 5th Element Perfume 150 ml', 'Bwitch Red Lace  Briefs', 'Peter England Men Formal Brown Belt')
# tensor([[[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6226, 2.6226, 2.6226,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6051, 2.6051, 2.6051,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6051, 2.6051, 2.6051,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         ...,
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
# ...
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         ...,
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]]]) ('Timberland Unisex Rubber Sole Brush Shoe Accessories', "Nike Men's Incinerate MSL White Blue Shoe", 'Lakme Absolute Matte Milan Red Lipstick 48', 'Jockey Women Blue Lounge Pants', 'Basics Men Red Casual Shoes', 'United Colors Of Benetton Women Grey Muffler', "Levi's Men White Brief", 'Gliders Men Esquire Red Flip Flops', 'Nike Women Grey Lunarglide +3 Sports Shoes', 'ADIDAS Women Pink Handbag', 'Tantra Women Flower Heart Black Long T-shirt', 'Levis Men Navy Blue Briefs', 'Peri Peri Women White Bra', 'Skagen Men Black Watch', 'Puma Women Dizzy  Black Belt', 'Aneri Women Blue & Brown Printed Kurta', "Myntra Men's Creative designs Black T-shirt", 'F Sports Men White Outlander Sports Shoes', 'Reebok Men Pack of 2 Pirates of the Caribbean Deos', 'Jockey ELANCE Men Grey Melange Y Front Briefs 1006', 'Nike Men Air Relentless 2 MSL White Sports Shoes', 'United Colors of Benetton Men Solid Blue Sweater', 'Fossil Women Brown Huarache Weave Belt', 'Spice Art Women Black Handbag', 'Indigo Nation Men Price catch Blue Shirts', 'Little Miss Girls Chatterbox Navy Blue Dress', 'Indigo Nation Men Club Satin Hot Stepper Navy Blue Shirt', 'Doodle Boys living Upto White Tshirt', 'Palm Tree Kids Girls Printed White Tops', 'GAS Men Grey Namib Shoes', 'Nike Women Downshifter White Sports Shoes', 'United Colors Of Benetton Women Light Winter Grey T-Shirts')
# tensor([[[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         ...,
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]],
#
#
#         [[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           ...,
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#           [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#          [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           ...,
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#           [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#          [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           ...,
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#           [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]]]) ('Kiara Women Teal Handbag', 'Mother Earth Women Printed Yellow Kurta', 'Baggit Women Beige Bag', 'ADIDAS Men Delhi Daredevil Blue Cap', 'Maxima Men Ssteele Silver Dial Watch', 'Revv Men Steel Bracelet', 'Peter England Unisex Black One Dayer Black Trolley Bag', 'Indigo Nation Men Printed Black T-shirt')

# %% [markdown]
# # 6. Fine-tuning with custom dataset

# %%
# Fine-tune the CLIP model
num_epochs = 20
model.train()
for epoch in range(num_epochs):
    for images, texts in data_loader:
        optimizer.zero_grad()
        # Encode images and texts
        images = images.to(device)
        texts = clip.tokenize(texts).to(device)
        # image_features = model.encode_image(images)
        # text_features = model.encode_text(texts)

        image_features = model.get_image_features(images)
        text_features = model.get_text_features(texts)

        # Compute the loss
        loss = criterion(image_features, text_features, torch.ones(images.shape[0]).to(device))

        # Backpropagation and optimization
        loss.backward()
        optimizer.step()  

    # Print epoch loss
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item()}")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Save the fine-tuned model
torch.save(model.state_dict(), "/content/drive/MyDrive/Saved_Model/CLIP_fine_tuned_model_Fashion.pt")

# %% [markdown]
# # 7. Testing the fine-tuned model

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.29.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)

# %%
import torch
from transformers import CLIPProcessor, CLIPModel, CLIPTokenizer
model_ID='openai/clip-vit-base-patch32'
# Initialize and load the pre-trained CLIP model
device = "cuda" if torch.cuda.is_available() else "cpu"
model = CLIPModel.from_pretrained(model_ID).to(device)
model.load_state_dict(torch.load("/content/drive/MyDrive/Saved_Model/CLIP_fine_tuned_model_Fashion.pt"))
model.eval()
# Out:
# CLIPModel(
#   (text_model): CLIPTextTransformer(
#     (embeddings): CLIPTextEmbeddings(
#       (token_embedding): Embedding(49408, 512)
#       (position_embedding): Embedding(77, 512)
#     )
#     (encoder): CLIPEncoder(
#       (layers): ModuleList(
#         (0-11): 12 x CLIPEncoderLayer(
#           (self_attn): CLIPAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (layer_norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): CLIPMLP(
#             (activation_fn): QuickGELUActivation()
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           )
#           (layer_norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (vision_model): CLIPVisionTransformer(
#     (embeddings): CLIPVisionEmbeddings(
#       (patch_embedding): Conv2d(3, 768, kernel_size=(32, 32), stride=(32, 32), bias=False)
#       (position_embedding): Embedding(50, 768)
#     )
#     (pre_layrnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (encoder): CLIPEncoder(
#       (layers): ModuleList(
#         (0-11): 12 x CLIPEncoderLayer(
#           (self_attn): CLIPAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (layer_norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): CLIPMLP(
#             (activation_fn): QuickGELUActivation()
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (layer_norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (post_layernorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (visual_projection): Linear(in_features=768, out_features=512, bias=False)
#   (text_projection): Linear(in_features=512, out_features=512, bias=False)
# )

# %%
import os
import torch
import skimage
import requests
import numpy as np
import pandas as pd
from PIL import Image
from io import BytesIO
import IPython.display
import matplotlib.pyplot as plt
from datasets import load_dataset
from collections import OrderedDict
from transformers import CLIPProcessor, CLIPModel, CLIPTokenizer
import torch
import clip
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader

# https://huggingface.co/datasets/conceptual_captions
image_data_test = load_dataset(
    "ashraq/fashion-product-images-small", split="train",
    )
# Out:
# WARNING:datasets.builder:Found cached dataset parquet (/root/.cache/huggingface/datasets/ashraq___parquet/ashraq--fashion-product-images-small-909c61a107795b31/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)

# %%
image_data_test_df = pd.DataFrame(image_data_test[1000:1300])

# %%
image_data_test_df.shape
# Out:
# (300, 11)

# %%
image_data_test_df.head()
# Out:
#       id gender masterCategory subCategory   articleType baseColour  season  \
# 0  47357  Women    Accessories        Bags  Mobile Pouch     Purple  Summer
# 1  26360  Women        Apparel     Topwear       Tshirts       Grey  Summer
# 2  12155  Women        Apparel  Bottomwear      Leggings      Beige    Fall
# 3  42625  Women    Accessories   Jewellery      Earrings     Silver  Winter
# 4   3502  Women        Apparel     Topwear       Tshirts      Black    Fall
#
#      year   usage                               productDisplayName  \
# 0  2012.0  Casual  Baggit Women Purple Phulrani Brush Mobile Pouch
# 1  2012.0  Casual                         Arrow Woman Grey T-shirt
# 2  2011.0  Ethnic               Aurelia Women Solid Beige Leggings
# 3  2016.0  Casual                           Estelle Women Earrings
# 4  2010.0  Sports                     ADIDAS Women's Black T-shirt
#
#                                                image
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 2  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 3  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 4  <PIL.JpegImagePlugin.JpegImageFile image mode=...

# %%
image_data_test_df.iloc[0]["image"]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80 at 0x7F1D5326EEF0>

# %%
image_data_test_df.iloc[0]["productDisplayName"]
# Out:
# 'Baggit Women Purple Phulrani Brush Mobile Pouch'

# %%
image_data_test_df.head()
# Out:
#       id gender masterCategory subCategory   articleType baseColour  season  \
# 0  47357  Women    Accessories        Bags  Mobile Pouch     Purple  Summer
# 1  26360  Women        Apparel     Topwear       Tshirts       Grey  Summer
# 2  12155  Women        Apparel  Bottomwear      Leggings      Beige    Fall
# 3  42625  Women    Accessories   Jewellery      Earrings     Silver  Winter
# 4   3502  Women        Apparel     Topwear       Tshirts      Black    Fall
#
#      year   usage                               productDisplayName  \
# 0  2012.0  Casual  Baggit Women Purple Phulrani Brush Mobile Pouch
# 1  2012.0  Casual                         Arrow Woman Grey T-shirt
# 2  2011.0  Ethnic               Aurelia Women Solid Beige Leggings
# 3  2016.0  Casual                           Estelle Women Earrings
# 4  2010.0  Sports                     ADIDAS Women's Black T-shirt
#
#                                                image
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 2  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 3  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 4  <PIL.JpegImagePlugin.JpegImageFile image mode=...

# %%
image_paths = image_data_test_df["image"].tolist()
texts = image_data_test_df["productDisplayName"].tolist()

# %% [markdown]
# #8. Create Embeddings: Text and Image Embeddings

# %% [markdown]
# ##a. Text Embeddings

# %%
def get_single_text_embedding(text):

  inputs = tokenizer(text, return_tensors = "pt").to(device)


  #OpenAI CLIP
  # text_embeddings=model.encode_text(inputs)

  #Huggingface CLIP
  text_embeddings = model.get_text_features(**inputs)

  # convert the embeddings to numpy array 
  embedding_as_np = text_embeddings.cpu().detach().numpy()

  return embedding_as_np

# %%
def get_all_text_embeddings(df, text_col):

   df["text_embeddings"] = df[str(text_col)].apply(get_single_text_embedding)

   return df

# %%
image_data_test_df = get_all_text_embeddings(image_data_test_df, "productDisplayName")

# %%
image_data_test_df.head()
# Out:
#       id gender masterCategory subCategory   articleType baseColour  season  \
# 0  47357  Women    Accessories        Bags  Mobile Pouch     Purple  Summer
# 1  26360  Women        Apparel     Topwear       Tshirts       Grey  Summer
# 2  12155  Women        Apparel  Bottomwear      Leggings      Beige    Fall
# 3  42625  Women    Accessories   Jewellery      Earrings     Silver  Winter
# 4   3502  Women        Apparel     Topwear       Tshirts      Black    Fall
#
#      year   usage                               productDisplayName  \
# 0  2012.0  Casual  Baggit Women Purple Phulrani Brush Mobile Pouch
# 1  2012.0  Casual                         Arrow Woman Grey T-shirt
# 2  2011.0  Ethnic               Aurelia Women Solid Beige Leggings
# 3  2016.0  Casual                           Estelle Women Earrings
# 4  2010.0  Sports                     ADIDAS Women's Black T-shirt
#
#                                                image  \
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 2  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 3  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 4  <PIL.JpegImagePlugin.JpegImageFile image mode=...
#
#                                      text_embeddings
# 0  [[0.48680207, -0.13457674, 0.23447752, 0.27955...
# 1  [[0.4848338, -0.13252051, 0.23810524, 0.287585...
# 2  [[0.48662147, -0.13119355, 0.24735664, 0.29280...
# 3  [[0.48817134, -0.1373209, 0.23396066, 0.289142...
# 4  [[0.49055868, -0.13413496, 0.23470466, 0.28780...

# %% [markdown]
# ##b. Image Embeddings

# %%
def get_single_image_embedding(my_image):

  image = processor(
      text = None,
      images = my_image, 
      return_tensors="pt"
  )["pixel_values"].to(device)

  embedding = model.get_image_features(image)

  # convert the embeddings to numpy array
  embedding_as_np = embedding.cpu().detach().numpy()

  return embedding_as_np

# %%
def get_all_images_embedding(df, img_column):

  df["img_embeddings"] = df[str(img_column)].apply(get_single_image_embedding)

  return df

# %%
image_data_test_df = get_all_images_embedding(image_data_test_df, "image")

# %%
image_data_test_df.head()
# Out:
#       id gender masterCategory subCategory   articleType baseColour  season  \
# 0  47357  Women    Accessories        Bags  Mobile Pouch     Purple  Summer
# 1  26360  Women        Apparel     Topwear       Tshirts       Grey  Summer
# 2  12155  Women        Apparel  Bottomwear      Leggings      Beige    Fall
# 3  42625  Women    Accessories   Jewellery      Earrings     Silver  Winter
# 4   3502  Women        Apparel     Topwear       Tshirts      Black    Fall
#
#      year   usage                               productDisplayName  \
# 0  2012.0  Casual  Baggit Women Purple Phulrani Brush Mobile Pouch
# 1  2012.0  Casual                         Arrow Woman Grey T-shirt
# 2  2011.0  Ethnic               Aurelia Women Solid Beige Leggings
# 3  2016.0  Casual                           Estelle Women Earrings
# 4  2010.0  Sports                     ADIDAS Women's Black T-shirt
#
#                                                image  \
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 2  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 3  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 4  <PIL.JpegImagePlugin.JpegImageFile image mode=...
#
#                                      text_embeddings  \
# 0  [[0.48680207, -0.13457674, 0.23447752, 0.27955...
# 1  [[0.4848338, -0.13252051, 0.23810524, 0.287585...
# 2  [[0.48662147, -0.13119355, 0.24735664, 0.29280...
# 3  [[0.48817134, -0.1373209, 0.23396066, 0.289142...
# 4  [[0.49055868, -0.13413496, 0.23470466, 0.28780...
#
#                                       img_embeddings
# 0  [[0.517499, -0.14258704, 0.25140327, 0.3074706...
# 1  [[0.5164769, -0.14258716, 0.25218743, 0.308085...
# 2  [[0.51677966, -0.14542654, 0.25374508, 0.30491...
# 3  [[0.51935065, -0.14340433, 0.25298405, 0.30686...
# 4  [[0.51931006, -0.14072834, 0.25106785, 0.30767...

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_images(images):

  for image in images:
    plt.imshow(image)
    plt.show()

def plot_images_by_side(top_images):

  index_values = list(top_images.index.values)
  list_images = [top_images.iloc[idx].image for idx in index_values] 
  list_captions = [top_images.iloc[idx].productDisplayName for idx in index_values] 
  similarity_score = [top_images.iloc[idx].cos_sim for idx in index_values] 

  n_row = n_col = 2

  _, axs = plt.subplots(n_row, n_col, figsize=(12, 12))
  axs = axs.flatten()
  for img, ax, caption, sim_score in zip(list_images, axs, list_captions, similarity_score):
      ax.imshow(img)
      sim_score = 100*float("{:.2f}".format(sim_score))
      ax.title.set_text(f"Caption: {caption}\nSimilarity: {sim_score}%")
  plt.show()

# %% [markdown]
# #9. Perform Similarity Search: Cosine

# %% [markdown]
# ## 1. Cosine Similarity Search

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def get_top_N_images(query, data, top_K=4, search_criterion="text"):

    """
    Retrieve top_K (5 is default value) articles similar to the query
    """
    # Text to image Search
    if(search_criterion.lower() == "text"):
      query_vect = get_single_text_embedding(query)

    # Image to image Search
    else: 
      query_vect = get_single_image_embedding(query)

    # Relevant columns
    revevant_cols = ["productDisplayName", "image", "cos_sim"]
    
    # Run similarity Search
    data["cos_sim"] = data["img_embeddings"].apply(lambda x: cosine_similarity(query_vect, x))

    data["cos_sim"] = data["cos_sim"].apply(lambda x: x[0][0])
    
    """
    Sort Cosine Similarity Column in Descending Order 
    Here we start at 1 to remove similarity with itself because it is always 1
    """
    most_similar_articles = data.sort_values(by='cos_sim', ascending=False)[1:top_K+1]
    
    return most_similar_articles[revevant_cols].reset_index()

# %%
image_data_test_df.columns
# Out:
# Index(['id', 'gender', 'masterCategory', 'subCategory', 'articleType',
#        'baseColour', 'season', 'year', 'usage', 'productDisplayName', 'image',
#        'text_embeddings', 'img_embeddings', 'cos_sim'],
#       dtype='object')

# %% [markdown]
# ### a. Text to image search

# %%
# query_caption = image_data_test_df.iloc[0].productDisplayName

query_caption="Red t-shirt"

# %%
top_images = get_top_N_images(query_caption, image_data_test_df)
print("Query: {}".format(query_caption))
top_images
# Out:
# Query: Red t-shirt
#    index                                 productDisplayName  \
# 0    183  Disney Kids Girl's Fun In The Fair Yellow Teen...
# 1     99                              Helix Men Black Watch
# 2     85            Forever New Women Pink Sleeveless Dress
# 3    241                      Lotto Unisex Canvas Pink Shoe
#
#                                                image   cos_sim
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...  0.999684
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...  0.999683
# 2  <PIL.JpegImagePlugin.JpegImageFile image mode=...  0.999681
# 3  <PIL.JpegImagePlugin.JpegImageFile image mode=...  0.999681

# %%
plot_images_by_side(top_images)

# %% [markdown]
# ### b. Image to image search

# %%
# query_image = image_data_test_df.iloc[0].image
query_image=Image.open("/content/images.jpg")
query_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=205x245 at 0x7F1D553B8AF0>

# %%
top_images = get_top_N_images(query_image, image_data_test_df, search_criterion="image")
plot_images_by_side(top_images)

# %% [markdown]
# #10. References
#
# 1. Y. Bisk et al., Experience Grounds Language (2020), EMNLP :https://arxiv.org/abs/2004.10151
# 2. A. Radford et al., Learning Transferable Visual Models From Natural Language Supervision (2021): https://arxiv.org/abs/2103.00020v1
#
# 3.   https://analyticsindiamag.com/how-clip-is-changing-computer-vision-as-we-know-it/
# 4.   https://www.pinecone.io/learn/clip/#resources
#
# 5. Vision Transformers (ViT) Explained + Fine-tuning in Python: https://youtu.be/qU7wO02urYU
#
# 6. OpenAI CLIP Explained | Multi-modal ML: https://youtu.be/fGwH2YoQkDM
#
# 7. Pretrained CLIP Model:
#     * https://github.com/openai/CLIP
#     * https://www.kaggle.com/code/gsfhjjj/openai-clip-with-train/notebook

# %% [markdown]
# #11. Observations
